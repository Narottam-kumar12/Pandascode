# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# DATASET DETAILS
#
# - Source: University of Chicago's Billings Hospital
# - Study Period: 1958–1970
# - Number of Instances: 306
# - Number of Features: 3 (plus one class label)
# - Type of Problem: Binary Classification

# %%
df = pd.read_csv('haberman.csv.xls')

# %%
df.sample(6)
# Out:
#      age  year  nodes  status
# 250   63    66      0       1
# 181   55    68     15       2
# 259   65    61      2       2
# 245   63    60      1       2
# 262   65    58      0       1
# 92    46    65     20       2

# %% [markdown]
# DIVE ATTRIBUTE
#
# - NUMERCALS - age , year , nodes
# - CATEGARICALS - status

# %% [markdown]
# Status
#
# 1. survived 5 years after surgery
# 2. the patient died within 5 years after surgery

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     305 non-null    int64
#  1   year    305 non-null    int64
#  2   nodes   305 non-null    int64
#  3   status  305 non-null    int64
# dtypes: int64(4)
# memory usage: 9.7 KB

# %% [markdown]
#  Conclusion,
#
#  - minmum age 30
#  - maximum age 78
#  - There is no any outliers
#  - Age column normaly distributed
#  - 73 percent people survived after surgery
#  - which people has high nodes,they have less chance to survive

# %%
df['age'].describe()
# Out:
# count    305.000000
# mean      52.357377
# std       10.678010
# min       30.000000
# 25%       44.000000
# 50%       52.000000
# 75%       60.000000
# max       78.000000
# Name: age, dtype: float64

# %%
df['age'].plot(kind = 'hist',bins = 40)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['age'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['age'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
df['status'].value_counts()/len(df['status'])*100
# Out:
# status
# 1    73.770492
# 2    26.229508
# Name: count, dtype: float64

# %%
df['nodes'].describe()
# Out:
# count    305.000000
# mean       4.032787
# std        7.200528
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        4.000000
# max       52.000000
# Name: nodes, dtype: float64

# %% [markdown]
# Bivariate anlysis

# %%
pd.crosstab(df['status'],df['age'],normalize='columns')
# Out:
# age      30   31   33        34   35   36   37   38        39   40  ...    69  \
# status                                                              ...
# 1       1.0  1.0  1.0  0.714286  1.0  1.0  1.0  0.9  0.833333  1.0  ...  0.75
# 2       0.0  0.0  0.0  0.285714  0.0  0.0  0.0  0.1  0.166667  0.0  ...  0.25
#
# age           70   71    72   73   74   75   76   77   78
# status
# 1       0.714286  1.0  0.75  1.0  0.5  1.0  1.0  1.0  0.0
# 2       0.285714  0.0  0.25  0.0  0.5  0.0  0.0  0.0  1.0
#
# [2 rows x 48 columns]

# %%
df[df['status'] == 1]['age'].plot(kind = 'kde',label = 'Survived')
df[df['status'] == 2]['age'].plot(kind = 'kde',label = 'Not Survived')

plt.legend()
plt.show()

# %%
pd.crosstab(df['status'],df['nodes'],normalize='columns')*100
# Out:
# nodes          0          1          2     3          4          5   \
# status
# 1       86.029412  80.487805  78.947368  65.0  76.923077  33.333333
# 2       13.970588  19.512195  21.052632  35.0  23.076923  66.666667
#
# nodes          6          7          8          9   ...     21         22  \
# status                                              ...
# 1       57.142857  71.428571  71.428571  33.333333  ...    0.0  66.666667
# 2       42.857143  28.571429  28.571429  66.666667  ...  100.0  33.333333
#
# nodes      23     24     25     28     30     35     46     52
# status
# 1         0.0    0.0  100.0  100.0  100.0    0.0  100.0    0.0
# 2       100.0  100.0    0.0    0.0    0.0  100.0    0.0  100.0
#
# [2 rows x 31 columns]
